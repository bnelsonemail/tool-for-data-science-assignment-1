# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ## In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# **Objectives:**
# - List popular languages for Data Science
# - List populare libraries used by Data Scientists in the R programming language
# - List of commonly used Open Source Tools used by Data Scientists
# - Provide an example of how to write a python programming code for calculations

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. R
# 3. SQL

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1. ggplot2
# 2. plotly
# 3. lattice
# 4. dplyr
# 5. tidyr
# 6. caret
# 7. randomForest
# 8. forecast

# %% [markdown]
# | **Data Science Tools** |
# |------------------------|
# | Jupyter Notebooks      |
# | R Studio               |
# | Apache Zeppelin        |

# %% [markdown]
# Below are a few examples of evaluating arithmetic expressions in Python

# %% [markdown]
# This a simple arithmetic expression to mutiply then add integers

# %%
math_prob = (3 * 4) + 5
print(math_prob)
# Out:
# 17

# %% [markdown]
# This will convert 200 minutes to hours by diving by 60

# %%
time_minutes = 200
time_hours = time_minutes / 60
print(f"{time_minutes} minutes of driving at 60 is equivalent to {time_hours:.2f} hours")
# Out:
# 200 minutes of driving at 60 is equalivalent to 3.33 hours

# %% [markdown]
# ## Author:
# Brice Nelson
